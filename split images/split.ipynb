# %%
from imutils import paths
import numpy as np
import shutil
import csv
import os

# %% [markdown]
# # Load pATH

# %%
image_dir = 'C:/Users/Tajr/Desktop/CGIAR Wheat/images/'

# %%
images_path = list(paths.list_images(image_dir))

# %%
images_path
# Out:
# ['C:/Users/Tajr/Desktop/CGIAR Wheat/images/01AJUu7l.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/01B4CV3K.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/01nUuQaf.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/02hINknf.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/02l3WRi5.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/02QNbFW3.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/02r3NCOn.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/02R9pCXz.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/02XgtYwT.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/03DVBfql.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/03suVk46.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/03vQEfIz.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/03Wa4HYF.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/04J3L9gf.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/04Opjmbk.jpeg',
#  'C:/Users/Tajr/Desktop/CGIAR Wheat/images/053h7FH8.jpeg',
# ...

# %% [markdown]
# # Open cSV fiLE

# %%
path = 'C:/Users/Tajr/Downloads/Train.csv'
path2 =  'C:/Users/Tajr/Downloads/SampleSubmission.csv'
open_submission = open(path2)
submission_reader = csv.reader(open_submission)
submission_data = list(submission_reader)

submissions = list()

for i in np.arange(1, len(submission_data)):
    submissions.append(submission_data[i][0])

submissions
# Out:
# ['F3LbWkZq',
#  '6P4wLVzI',
#  'Tn6HIrdS',
#  'EYM5R1TK',
#  'fkcevlA0',
#  'QumzsyqU',
#  'I5axlwYR',
#  'C95wnKFx',
#  '79kzEdvF',
#  'YSCVBnkr',
#  'Zmw5jCv8',
#  'a1dESxDL',
#  'yxR8khFG',
#  'qiAeBInp',
#  'nlsuxPb1',
#  'QipL41yR',
#  'ez51RTAd',
#  'OHs5wU4D',
#  '8mAFW0O5',
#  'h1q6dJaE',
#  'lzbf64tR',
#  'fbFrvuMy',
#  'YL9uPlKQ',
#  '3fmyxTPW',
#  'TRiWtzmH',
#  'ea5vKYbg',
#  'ev4J9Znk',
#  'JlzBWAiQ',
#  '02r3NCOn',
#  '5yzDhIG9',
#  'uFov7HMj',
#  'Mdbf7phC',
#  'XEqn72xH',
#  'yOpjAIEd',
#  'csKGjRnZ',
#  'sLmqi4MF',
#  'n4x93S0A',
#  'cjLbHRd2',
#  '5yBodArn',
#  '2RJg5kn1',
#  'yF85wofa',
#  'WEzAFuQd',
#  'u8X70MTq',
#  '0BhesCpG',
#  'd5gMpF8s',
#  'qOXf7gQG',
#  'SHIy1VBR',
#  'AiDCWG4w',
#  'aVItZUgv',
#  'TEpU9c0h',
#  'pBvjka2l',
#  'fA9P6aYp',
#  'ArLekHmw',
#  'dx9zDI1e',
#  '7K5V1qG4',
#  'boG3WrF7',
#  'R2GBX9wI',
#  'XrOI6yVi',
#  'eclVvtOL',
#  'GsXZT1Hu',
#  'SiyhPHu5',
#  '98yimZvV',
#  'dx2tF06s',
#  'EYvnWRTh',
#  'KGhCX2oB',
#  'tldHprfI',
# ...

# %%
train_map = open(path)
train_map_reader = csv.reader(train_map)
train_map_data = list(train_map_reader)

# %%
train_map_data[-1]
# Out:
# ['LXUDkic1', '1', '1']

# %%
quality_one = {'one': [], 'two': [], 'three':[],'four': [], 'five': [], 'six':[], 'seven':[]}
quality_two = {'one': [], 'two': [], 'three':[],'four': [], 'five': [], 'six':[], 'seven':[]}

for (i, arr) in enumerate(train_map_data):
    if i == 0:
        continue
    elif i > 0:
        if arr[1] == str(1) and arr[2] == str(1):
            quality_one['one'].append(arr[0])
        elif arr[1] == str(1) and arr[2] ==str(2):
            quality_two['one'].append(arr[0])
        
        if arr[1] == str(2) and arr[2] == str(1):
            quality_one['two'].append(arr[0])
        elif arr[1] == str(2) and arr[2] ==str(2):
            quality_two['two'].append(arr[0])
            
        if arr[1] == str(3) and arr[2] == str(1):
            quality_one['three'].append(arr[0])
        elif arr[1] == str(3) and arr[2] ==str(2):
            quality_two['three'].append(arr[0])
            
        if arr[1] == str(4) and arr[2] == str(1):
            quality_one['four'].append(arr[0])
        elif arr[1] == str(4) and arr[2] ==str(2):
            quality_two['four'].append(arr[0])
            
        if arr[1] == str(5) and arr[2] == str(1):
            quality_one['five'].append(arr[0])
        elif arr[1] == str(5) and arr[2] ==str(2):
            quality_two['five'].append(arr[0])
            
        if arr[1] == str(6) and arr[2] == str(1):
            quality_one['six'].append(arr[0])
        elif arr[1] == str(6) and arr[2] ==str(2):
            quality_two['six'].append(arr[0])
            
        if arr[1] == str(7) and arr[2] == str(1):
            quality_one['seven'].append(arr[0])
        elif arr[1] == str(7) and arr[2] ==str(2):
            quality_two['seven'].append(arr[0])
            
            
    else:
        break

# %%
print(len(quality_one['one']))
print(len(quality_one['two']))
print(len(quality_one['three']))
print(len(quality_one['four']))
print(len(quality_one['five']))
print(len(quality_one['six']))
print(len(quality_one['seven']))
# Out:
# 3057
# 925
# 0
# 592
# 841
# 421
# 2003

# %%
arr = np.array([3057, 925, 689, 592, 841, 421, 2003])

weight = arr.max() / arr
weight
# Out:
# array([1.        , 3.30486486, 4.43686502, 5.16385135, 3.63495838,
#        7.26128266, 1.52621068])

# %%
one = len(quality_one['one'])
two = len(quality_one['two'])
three = len(quality_one['three'])
four = len(quality_one['four'])
five = len(quality_one['five'])
six = len(quality_one['six'])
seven = len(quality_one['seven'])

total_one = one + two + three + four + five + six + seven
total_one
# Out:
# 7839

# %%
print(len(quality_two['one']))
print(len(quality_two['two']))
print(len(quality_two['three']))
print(len(quality_two['four']))
print(len(quality_two['five']))
print(len(quality_two['six']))
print(len(quality_two['seven']))
# Out:
# 0
# 464
# 689
# 1120
# 251
# 0
# 332

# %%
one = len(quality_two['one'])
two = len(quality_two['two'])
three = len(quality_two['three'])
four = len(quality_two['four'])
five = len(quality_two['five'])
six = len(quality_two['six'])
seven = len(quality_two['seven'])

total_two = one + two + three + four + five + six + seven
total_two
# Out:
# 2856

# %%
total = total_one + total_two

# %%
total
# Out:
# 10695

# %%
base_dir = 'C:/Users/Tajr/Desktop/quality two'
data_dir = image_dir

# %%
base_dir
# Out:
# 'C:/Users/Tajr/Desktop/quality two'

# %%
data_dir
# Out:
# 'C:/Users/Tajr/Desktop/CGIAR Wheat/images/'

# %%
def mk_dir(newdir, mode=0o777):
    try:
        os.makedirs(newdir, mode)
    except OSError as err:
        return err

# %%
one = os.path.join(base_dir, 'one/')
mk_dir(one)

two = os.path.join(base_dir, 'two/')
# os.mkdir(two)
mk_dir(two)


three = os.path.join(base_dir, 'three/')
# os.mkdir(three)
mk_dir(three)


four = os.path.join(base_dir, 'four/')
# os.mkdir(four)
mk_dir(four)


five = os.path.join(base_dir, 'five/')
# os.mkdir(five)
mk_dir(five)


six = os.path.join(base_dir, 'six/')
# os.mkdir(six)
mk_dir(six)


seven = os.path.join(base_dir, 'seven/')
# os.mkdir(seven)
mk_dir(seven)
# Out:
# FileExistsError(17, 'Cannot create a file when that file already exists')

# %%
submission = os.path.join(base_dir, 'submission/')
# os.mkdir(seven)
mk_dir(submission)

# %%
def image_splitor(paths):
    file_names = []
    
    for (i, path) in enumerate(paths):
        image_file = path.split('/')[-1]
        name = path.split('/')[-1].split('.')[0]
        
        file_names.append(name)
    
    return file_names
        
#         for (j, name) in enumerate(dict['five']):
#             src = os.path.join(data_dir, image_file)
#             dst = "C:/Users/Tajr/Desktop/five/{}.{}.jpeg".format(name, j)
#             shutil.copyfile(src, dst)
            
#         for name in dict['two']:
#             src = os.path.join(data_dir, image_file)
#             dst = two
#             shutil.copy(src, dst)
            
#         for name in dict['three']:
#             src = os.path.join(data_dir, image_file)
#             dst = three
#             shutil.copy(src, dst)
            
#         for name in dict['four']:
#             src = os.path.join(data_dir, image_file)
#             dst = four
#             shutil.copy(src, dst)
        
#         for name in dict['five']:
#             src = os.path.join(data_dir, image_file)
#             dst = five
#             shutil.copy(src, dst)
        
#         for name in dict['six']:
#             src = os.path.join(data_dir, image_file)
#             dst = six
#             shutil.copy(src, dst)
        
#         for name in dict['seven']:
#             src = os.path.join(data_dir, image_file)
#             dst = seven
#             shutil.copy(src, dst)

# %%
file_names = image_splitor(images_path)

# %%
len(file_names)
# Out:
# 14253

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['one']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = one
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['two']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = two
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['three']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = three
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['four']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = four
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['five']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = five
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['six']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = six
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for (i, name )in enumerate(file_names):
    if name in quality_two['seven']:
        src = os.path.join(data_dir, '{}.jpeg'.format(name))
        dst = seven
        shutil.copy(src, dst)
print('complete')
# Out:
# complete

# %%
for name in submissions:
    src = os.path.join(data_dir, '{}.jpeg'.format(name))
    dst = submission
    shutil.copy(src, dst)
print('complete')
# Out:
# complete
